#   inflating: Kick/Kick Mighty 12.wav
#   inflating: Kick/Kick Mighty 13.wav
#   inflating: Kick/Kick Mighty 14.wav
#   inflating: Kick/Kick Mighty 15.wav
#   inflating: Kick/Kick Mighty 16.wav
#   inflating: Kick/Kick Mighty 2.wav
#   inflating: Kick/Kick Mighty 3.wav
#   inflating: Kick/Kick Mighty 4.wav
#   inflating: Kick/Kick Mighty 5.wav
#   inflating: Kick/Kick Mighty 6.wav
#   inflating: Kick/Kick Mighty 7.wav
#   inflating: Kick/Kick Mighty 8.wav
#   inflating: Kick/Kick Mighty 9.wav
#   inflating: Kick/Kick More 1.wav
#   inflating: Kick/Kick More 2.wav
#   inflating: Kick/Kick NYC 1.wav
#   inflating: Kick/Kick NYC 2.wav
#   inflating: Kick/Kick Plopper 1.wav
#   inflating: Kick/Kick Plopper 2.wav
#   inflating: Kick/Kick Redmenn 1.wav
#   inflating: Kick/Kick Redmenn 2.wav
#   inflating: Kick/Kick Roshi 1.wav
#   inflating: Kick/Kick Roshi 2.wav
#   inflating: Kick/Kick Roshi 3.wav
#   inflating: Kick/Kick Sapphire 1.wav
#   inflating: Kick/Kick Sapphire 2.wav
#   inflating: Kick/Kick Saraya 1.wav
#   inflating: Kick/Kick Saraya 2.wav
#   inflating: Kick/Kick SouthTown 1.wav
#   inflating: Kick/Kick SouthTown 2.wav
#   inflating: Kick/Kick SouthTown 3.wav
#   inflating: Kick/Kick Synesthesia DS 1.wav
#   inflating: Kick/Kick Synesthesia DS 2.wav
#   inflating: Kick/Kick TheGrudge 1.wav
#   inflating: Kick/Kick TheGrudge 2.wav
#   inflating: Kick/Kick TrunkJuice.wav
#   inflating: Kick/Kick Turnt.wav
#   inflating: Kick/Kick VintageMachine 1.wav
#   inflating: Kick/Kick VintageMachine 2.wav
#   inflating: Kick/Kick Yaro 1.wav
#   inflating: Kick/Kick Yaro 2.wav

# %%
import librosa
from scipy.signal import butter, filtfilt
import numpy as np
import os
import matplotlib.pyplot as plt
from glob import glob

# %%
y
# Out:
# array([0.        , 0.00079346, 0.00169373, ..., 0.        , 0.        ,
#        0.        ], dtype=float32)

# %%
# load the audio file
sample_path = '/content/drive/MyDrive/audio diffusion/samples/Kick'
os.chdir(sample_path)
files = glob("*.wav")

# visualizing log-mel spectrogram
def compute_logmel_spectrogram(y, sr, n_mels=128, hop_length=512):
    mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels, hop_length=hop_length)
    logmel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)
    return logmel_spectrogram

for file in files:
  sample_rate, samples = wavfile.read(file)

  # Load the audio file
  y, sr = librosa.load(file, sr=sample_rate)

  y = np.pad(y, (0, 44100-y.shape[0])) # or 44100

  # Compute log-mel spectrogram
  logmel_spectrogram = compute_logmel_spectrogram(y, sr=sr)

  # Display the log-mel spectrogram
  plt.figure(figsize=(8, 4))
  librosa.display.specshow(logmel_spectrogram, sr=sr, hop_length=512, x_axis='time', y_axis='mel')
  plt.colorbar(format='%+2.0f dB')
  plt.title('Log-Mel Spectrogram, ' + file)
  plt.show()
# Out:
# <ipython-input-31-4e5c1a5e0b4d>:13: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, samples = wavfile.read(file)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-4e5c1a5e0b4d> in <cell line: 12>()
#      16   y, sr = librosa.load(file, sr=sample_rate)
#      17
# ---> 18   y = np.pad(y, (0, 44100-y.shape[0])) # or 44100
#      19
#      20   # Compute log-mel spectrogram
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/arraypad.py in pad(array, pad_width, mode, **kwargs)
#     746
#     747     # Broadcast to shape (array.ndim, 2)
# --> 748     pad_width = _as_pairs(pad_width, array.ndim, as_index=True)
#     749
#     750     if callable(mode):
#
# /usr/local/lib/python3.10/dist-packages/numpy/lib/arraypad.py in _as_pairs(x, ndim, as_index)
#     512             x = x.ravel()  # Ensure x[0], x[1] works
#     513             if as_index and (x[0] < 0 or x[1] < 0):
# --> 514                 raise ValueError("index can't contain negative values")
#     515             return ((x[0], x[1]),) * ndim
#     516
#
# ValueError: index can't contain negative values

# %%
from scipy.io import wavfile
# visualizing log-mel spectrogram
def compute_logmel_spectrogram(y, sr, n_mels=128, hop_length=512):
    mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=n_mels, hop_length=hop_length)
    logmel_spectrogram = librosa.power_to_db(mel_spectrogram, ref=np.max)
    return logmel_spectrogram

# load the audio file
audio_file_path = '/content/drive/MyDrive/audio diffusion/samples/Kick/Kick Alessya DS 1.wav'
sample_rate, samples = wavfile.read(audio_file_path)

# Load the audio file
y, sr = librosa.load(audio_file_path, sr=sample_rate)

y = np.pad(y, (0, 32000-y.shape[0])) # or 44100

# Compute log-mel spectrogram
logmel_spectrogram = compute_logmel_spectrogram(y, sr=sr)

# Display the log-mel spectrogram
plt.figure(figsize=(8, 4))
librosa.display.specshow(logmel_spectrogram, sr=sr, hop_length=512, x_axis='time', y_axis='mel')
plt.colorbar(format='%+2.0f dB')
plt.title('Log-Mel Spectrogram')
plt.show()
# Out:
# <ipython-input-4-561ae41a2334>:10: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, samples = wavfile.read(audio_file_path)

# %%
# load the audio file
audio_file_path = '/content/Kick/Kick Alessya DS 2.wav'
sample_rate, samples = wavfile.read(audio_file_path)
# Out:
# <ipython-input-38-493f0c58d362>:3: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, samples = wavfile.read(audio_file_path)

# %%
sample_rate
# Out:
# 44100

# %%
y
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
logmel_spectrogram
# Out:
# array([[-1.57395248e+01, -1.78682060e+01, -1.69020367e+01, ...,
#         -8.00000000e+01, -8.00000000e+01, -8.00000000e+01],
#        [-1.16102295e+01, -4.82717133e+00, -1.53020859e+00, ...,
#         -8.00000000e+01, -8.00000000e+01, -8.00000000e+01],
#        [-1.00741215e+01, -1.21700668e+00, -2.68516541e-02, ...,
#         -8.00000000e+01, -8.00000000e+01, -8.00000000e+01],
#        ...,
#        [-8.00000000e+01, -8.00000000e+01, -8.00000000e+01, ...,
#         -8.00000000e+01, -8.00000000e+01, -8.00000000e+01],
#        [-8.00000000e+01, -8.00000000e+01, -8.00000000e+01, ...,
#         -8.00000000e+01, -8.00000000e+01, -8.00000000e+01],
#        [-8.00000000e+01, -8.00000000e+01, -8.00000000e+01, ...,
#         -8.00000000e+01, -8.00000000e+01, -8.00000000e+01]], dtype=float32)

# %%
plt.imshow(logmel_spectrogram, color=)

# %%
file
# Out:
# 'Kick Abbrand 1.wav'
